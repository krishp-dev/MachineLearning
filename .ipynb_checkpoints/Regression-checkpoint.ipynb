# %%
from sklearn.datasets import fetch_california_housing

data =fetch_california_housing()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88    -122.23
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86    -122.22
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85    -122.24
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85    -122.25
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85    -122.25

# %%
x=df.drop("HouseAge",axis=1)
y=df["HouseAge"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
ms=cross_val_score(lr,x_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
ms
# Out:
# array([-129.87068228, -127.67496202, -132.61058926, -126.71123393,
#        -128.06628831])

# %%
np.mean(ms)
# Out:
# np.float64(-128.98675116054406)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([27.2336003 , 31.28410073, 34.16739658, ..., 25.97957984,
#        26.55247801, 29.13627647])

# %%
import seaborn as sns
sns.displot(y_pred-y_test,kind='kde')

# %%
from sklearn.metrics import r2_score
score=r2_score(y_pred,y_test)

# %%
score
# Out:
# -3.2440742583187285

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# alpha=Lambda(Hyperparameter)

# %% [markdown]
# alpha implemented by GridSearchCV

# %%
ridge_resgression=Ridge()

# %%
ridge_resgression
# Out:
# Ridge()

# %% [markdown]
# write all the possible values of alpha you want to test or check

# %%
parameters={'alpha':[1,2,3,5,7,9,10,20,50,75,79,60,80,62]}

# %%
ridgecv=GridSearchCV(ridge_resgression,parameters,scoring='neg_mean_squared_error',cv=5)

# %%
ridgecv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 2, 3, 5, 7, 9, 10, 20, 50, 75, 79, 60, 80,
#                                    62]},
#              scoring='neg_mean_squared_error')

# %%
print(ridgecv.best_params_)
# Out:
# {'alpha': 1}

# %%
print(ridgecv.best_score_)
# Out:
# -128.98694411941386

# %%
ridge_pred=ridgecv.predict(x_test)

# %%
score=r2_score(ridge_pred,y_test)

# %%
score
# Out:
# -3.2471351333037575

# %%
from sklearn.linear_model import Lasso

# %%
la=Lasso()

# %%
la
# Out:
# Lasso()

# %%
parameters={'alpha':[1,2,3,5,7,9,10,20,50,75,79,60,80,62]}

# %%
lassocv=GridSearchCV(la,parameters,scoring='neg_mean_squared_error',cv=5)

# %%
lassocv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1, 2, 3, 5, 7, 9, 10, 20, 50, 75, 79, 60, 80,
#                                    62]},
#              scoring='neg_mean_squared_error')

# %%
print(lassocv.best_params_)
# Out:
# {'alpha': 1}

# %%
print(lassocv.best_score_)
# Out:
# -142.15983768058805
