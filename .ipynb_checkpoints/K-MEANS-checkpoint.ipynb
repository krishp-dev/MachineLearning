# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import numpy as np 
import pandas as pd

# %%
x,y=make_blobs(n_samples=1000,centers=3,n_features=2,random_state=23)

# %%
plt.scatter(x[:,0
            ],x[:,1])

# %%
x.shape
# Out:
# (1000, 2)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.cluster import KMeans
wcss=[]
for k in range(1,11):
    kmean=KMeans(n_clusters=k,init='k-means++')
    kmean.fit(x_train)
    wcss.append(kmean.inertia_)

# %%
wcss
# Out:
# [34827.57682552021,
#  7935.437286145418,
#  1319.2730531585612,
#  1140.4677884655125,
#  1073.6292482884223,
#  952.8848299646083,
#  757.1439762085707,
#  678.03042578491,
#  595.9107782857882,
#  545.8813131515262]

# %%
plt.plot(range(1,11),wcss)
plt.xticks(range(1,11))
plt.xlabel("Number of clusters")
plt.ylabel('wcss')
plt.show()

# %%
xtrain_output=kmean.fit_predict(x_train)

# %%
xtest_output=kmean.predict(x_test)

# %%
pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.5-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from kneed) (2.1.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\dell\appdata\local\programs\python\python313\lib\site-packages (from kneed) (1.15.2)
# Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from kneed import KneeLocator
kl=KneeLocator(range(1,11),wcss,curve='convex',direction='decreasing')
kl.elbow
# Out:
# np.int64(3)

# %%
from sklearn.metrics import silhouette_score 
silhouette=[]
for i in range(2,11):
    kmeans=KMeans(n_clusters=i,init='k-means++')
    kmeans.fit(x_train)
    score=silhouette_score(x_train,kmeans.labels_)
    silhouette.append(score)

# %%
silhouette
# Out:
# [np.float64(0.7281443868598331),
#  np.float64(0.8071181203797672),
#  np.float64(0.6061298889229664),
#  np.float64(0.4800372084432812),
#  np.float64(0.4754814461826081),
#  np.float64(0.3395478800597239),
#  np.float64(0.3421354262275606),
#  np.float64(0.34590207520450655),
#  np.float64(0.34125526208256396)]

# %%
plt.plot(range(2,11),silhouette)
plt.xticks(range(2,11))
plt.xlabel("clusters")
plt.ylabel("Silhoute coeff")
# Out:
# Text(0, 0.5, 'Silhoute coeff')
